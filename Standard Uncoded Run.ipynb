# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, QISKitError
from qiskit import available_backends, register, execute, get_backend
from qiskit.tools.visualization import circuit_drawer, plot_histogram, plot_state
from qiskit.tools.qi.qi import state_fidelity
import random
import pickle

# helpful function
state_overlap = lambda state1, state2: np.absolute(np.dot(state1.conj().T,state2))**2

#setup
import sys, getpass
try:
    sys.path.append("../../") # go to parent dir
    import Qconfig
    qx_config = {
        "APItoken": Qconfig.APItoken,
        "url": Qconfig.config['url']}
    print('Qconfig loaded from %s.' % Qconfig.__file__)
except:
    APItoken = getpass.getpass('Please input your token and hit enter: ')
    qx_config = {
        "APItoken": APItoken,
        "url":"https://quantumexperience.ng.bluemix.net/api"}
    print('Qconfig.py not found in qiskit-tutorial directory; Qconfig loaded using user input.')
    
#matlab stuff
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from numpy import matrix
from math import pi

#set api token 
QX_TOKEN = "96c86855a5c381875a4ea3a956a7deafbbbbb82e5912ec73655c7c444d2597a7364eda2fa558e4e37f672640029443216899825f945d5a0684e31b796837ce61"
QX_URL = "https://quantumexperience.ng.bluemix.net/api"


#register token and url
register(QX_TOKEN, QX_URL)


# for getting a backend
def lowest_pending_jobs():
    """Returns the backend with lowest pending jobs."""
    list_of_backends = available_backends(
        {'local': False, 'simulator': False})
    device_status = [get_backend(backend).status
                     for backend in list_of_backends]

    best = min([x for x in device_status if x['available'] is True],
               key=lambda x: x['pending_jobs'])
    return best['name']

# query for available backends
print("Available backends: ", available_backends())

device_name = lowest_pending_jobs()
device = get_backend(device_name)
device_coupling = device.configuration['coupling_map']
print(device)
print(device_coupling)


backend = 'local_statevector_simulator'

# parse a string of gens
def addCliffGens(qc, string):
    for char in string:
        i = int(char)
        if i==0:
            qc.x(qr[0])
        elif i==1:
            qc.x(qr[1])
        elif i==2:
            qc.z(qr[0])
        elif i==3:
            qc.z(qr[1])
        elif i ==4:
            qc.h(qr[0])
            qc.h(qr[1])
            qc.swap(qr[0],qr[1])
        elif i == 5:
            qc.cz(qr[0],qr[1])
            qc.z(qr[0])
            qc.z(qr[1])
        elif i==6:
            qc.cx(qr[0],qr[1])
        elif i==7:
            qc.cx(qr[1],qr[0])
            
def findGenString(mat):
    for key, value in r2group.items():
        if np.array_equal(value, mat):
            return key
    print("OH NO")
    return None
        
# invert cliff gens in most stupid way possible
def invertCliffGens(qc, mat):
    genString = findGenString(mat)
    for char in genString[::-1]:
        i = int(char)
        if i==0:
            qc.x(qr[0])
        elif i==1:
            qc.x(qr[1])
        elif i==2:
            qc.z(qr[0])
        elif i==3:
            qc.z(qr[1])
        elif i ==4:
            qc.swap(qr[0],qr[1])
            qc.h(qr[0])
            qc.h(qr[1])
        elif i == 5:
            qc.z(qr[0])
            qc.z(qr[1])
            qc.cz(qr[0],qr[1])
        elif i==6:
            qc.cx(qr[0],qr[1])
        elif i==7:
            qc.cx(qr[1],qr[0])

def addRandCliff(qc, mat):
    genString = random.choice(list(r2group.keys()))
    addCliffGens(qc,genString)
    qc.barrier(qr)
    return np.matmul(mat,r2group[genString])


pickle_in = open("r2group.pickle", "rb")
r2group = pickle.load(pickle_in)

trials = 30
reps = 5
shots = 1

for i in range(trials):
    length = 2+3*i
    print(length)
    
    circuits = []
    
    # run our trials
    for i in range(reps):
    
        # run one trial of given length 
        mat = r2group[""]
        n = 2
        qr = QuantumRegister(n)
        cr = ClassicalRegister(n)
        qc = QuantumCircuit(qr, cr)

        # add the first m-1 clifford gates
        for i in range(length):
            mat = addRandCliff(qc,mat)
        
        # invert everything
        invertCliffGens(qc,mat)
        
        '''
        # measure
        for i in range(n):
            qc.measure(qr[i],cr[i])'''
            
        circuits.append(qc)
    print("got")
    job = execute(circuits, backend, shots = shots)
    print("here")
    result = job.result()
    print("nice")
    stateVec = result.get_statevector(circuits[0])
    print(stateVec)
    counts = {}
    for trialNum in range(reps):
        trial = result.get_counts(circuits[trialNum])
        for key in trial:
            if key not in counts.keys():
                counts[key]=0
            counts[key] = counts[key] + trial[key]
    print(counts)
# Out:
# Qconfig loaded from C:\Users\ddrsq\OneDrive\Quantum\quantum_rb\Qconfig.py.
# Available backends:  ['local_qasm_simulator', 'ibmq_qasm_simulator', 'local_unitary_simulator', 'ibmqx4', 'local_statevector_simulator', 'local_clifford_simulator', 'ibmqx5', 'ibmqx2']
# ibmqx5
# [[1, 0], [1, 2], [2, 3], [3, 4], [3, 14], [5, 4], [6, 5], [6, 7], [6, 11], [7, 10], [8, 7], [9, 8], [9, 10], [11, 10], [12, 5], [12, 11], [12, 13], [13, 4], [13, 14], [15, 0], [15, 2], [15, 14]]
# 2
# got
# here
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\ddrsq\Anaconda3\lib\concurrent\futures\process.py", line 175, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "C:\Users\ddrsq\Anaconda3\lib\site-packages\qiskit\backends\local\statevector_simulator_cpp.py", line 46, in _run_job
#     self._validate(qobj)
#   File "C:\Users\ddrsq\Anaconda3\lib\site-packages\qiskit\backends\local\statevector_simulator_cpp.py", line 87, in _validate
#     "not support measure or reset.".format(circuit['name']))
# qiskit.backends.local._simulatorerror.SimulatorError: 'In circuit circuit2591: statevector simulator does not support measure or reset.'
# """
#
# The above exception was the direct cause of the following exception:
#
# SimulatorError                            Traceback (most recent call last)
# <ipython-input-26-f659445bab42> in <module>()
#     169     job = execute(circuits, backend, shots = shots)
#     170     print("here")
# --> 171     result = job.result()
#     172     print("nice")
#     173     stateVec = result.get_statevector(circuits[0])
#
# ~\Anaconda3\lib\site-packages\qiskit\backends\local\localjob.py in result(self, timeout)
#      55             concurrent.futures.CancelledError: if job cancelled before completed.
#      56         """
# ---> 57         return self._future.result(timeout=timeout)
#      58
#      59     def cancel(self):
#
# ~\Anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433             else:
#     434                 raise TimeoutError()
#
# ~\Anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# SimulatorError: 'In circuit circuit2591: statevector simulator does not support measure or reset.'
