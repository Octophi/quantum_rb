# %%
# Author: Joey Li, Atsushi Hu, Becca Shapiro
# Date: 7/20/18

# Implements real randomized benchmarking procedure on the [[4,2,2]] code
# Draws fixed number of gates from R(2) group and concatenates them to make a circuit then inverts the gates
# Data gathered is used to compute infidelity rate for procedure
# See paper for more details

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, QISKitError
from qiskit import available_backends, register, execute, get_backend
from qiskit.tools.visualization import circuit_drawer, plot_histogram, plot_state
from qiskit.tools.qi.qi import state_fidelity
import random
import pickle
import time
import datetime
import xlsxwriter

#setup
import sys, getpass
try:
    sys.path.append("../../") # go to parent dir
    import Qconfig
    qx_config = {
        "APItoken": Qconfig.APItoken,
        "url": Qconfig.config['url']}
    print('Qconfig loaded from %s.' % Qconfig.__file__)
except:
    APItoken = getpass.getpass('Please input your token and hit enter: ')
    qx_config = {
        "APItoken": APItoken,
        "url":"https://quantumexperience.ng.bluemix.net/api"}
    print('Qconfig.py not found in qiskit-tutorial directory; Qconfig loaded using user input.')
    
#matlab stuff
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from numpy import matrix
from math import pi

#set 
QX_URL = "https://quantumexperience.ng.bluemix.net/api"
QX_TOKEN = "06704f99fc6dd68ab5ae2663f0861723406de8b4553cacdabdf500292c937717442daa90c2ffa19109cfb9114adb7c87711a08860d34d1da9332ac664e4e24a7"

#register token and url
register(QX_TOKEN, QX_URL)

backend = 'ibmqx4'

# add phase gate 
def addPhase(qc):
    qc.h(qr[perm[0]])
    qc.h(qr[perm[1]])
    swap(perm,0,1)
    qc.s(qr[perm[0]]) 
    qc.barrier(qr)
    
# remove phase gate
def removePhase(qc):
    qc.sdg(qr[perm[0]])
    swap(perm,0,1)
    qc.h(qr[perm[1]])
    qc.h(qr[perm[0]])
    qc.barrier(qr)

# compile into different states
def compilation(qc,i,perm):
    if i == 0: 
        qc.iden(qr[perm[0]])
        qc.iden(qr[perm[1]])
    elif i == 1:
        qc.x(qr[perm[0]])
        qc.iden(qr[perm[1]])
    elif i == 2:
        qc.iden(qr[perm[0]])
        qc.x(qr[perm[1]])
    elif i == 3:
        qc.x(qr[perm[0]])
        qc.x(qr[perm[1]])
    qc.barrier(qr)
        
            
# parse a string of gens
def addCliffGens(qc, string,perm):
    for char in string:
        i = int(char)
        if i==0:
            qc.x(qr[perm[0]])
        elif i==1:
            qc.x(qr[perm[1]])
        elif i==2:
            qc.z(qr[perm[0]])
        elif i==3:
            qc.z(qr[perm[1]])
        elif i ==4:
            qc.h(qr[perm[0]])
            qc.h(qr[perm[1]])
            swap(perm,0,1)
        elif i == 5:
            qc.cz(qr[perm[0]],qr[perm[1]])
            qc.z(qr[perm[0]])
            qc.z(qr[perm[1]])
        elif i==6:
            qc.cx(qr[perm[0]],qr[perm[1]])
        elif i==7:
            qc.cx(qr[perm[1]],qr[perm[0]])
        elif i==8:
            qc.barrier()
            
# search dictionary for key corresponding to matrix
def findGenString(mat):
    for key, value in signedGroup.items():
        if np.array_equal(value, mat):
            return key
    print("OH NO")
    return None
        
# invert cliff gens
def invertCliffGens(qc, genString,perm):
    for char in genString[::-1]:
        i = int(char)
        if i==0:
            qc.x(qr[perm[0]])
        elif i==1:
            qc.x(qr[perm[1]])
        elif i==2:
            qc.z(qr[perm[0]])
        elif i==3:
            qc.z(qr[perm[1]])
        elif i ==4:
            swap(perm,0,1)
            qc.h(qr[perm[0]])
            qc.h(qr[perm[1]])
        elif i == 5:
            qc.z(qr[perm[0]])
            qc.z(qr[perm[1]])
            qc.cz(qr[perm[0]],qr[perm[1]])
        elif i==6:
            qc.cx(qr[perm[0]],qr[perm[1]])
        elif i==7:
            qc.cx(qr[perm[1]],qr[perm[0]])
    qc.barrier(qr)

# add a random real clifford            
def addRandCliff(qc, mat,perm):
    genString = random.choice(list(r2group.keys()))
    addCliffGens(qc,genString,perm)
    qc.barrier(qr)
    return np.matmul(mat,r2group[genString])

# converts 0-3 to binary strings
def toBinString(num):
    if num ==0:
        return "00"
    elif num == 1:
        return "01"
    elif num == 2:
        return "10"
    elif num == 3:
        return "11"
    else:
        print("OH NO")


def writeToExcel(results,initialState,row,col):
    states = ["00","01","10","11"]

    worksheet.write(row,1,initialState)
    #worksheet.write(row,1,key)
    col = 2
    for state in states:
        try:
            worksheet.write(row,col,results[state])
            
        except:
            print(state+"does not exist")
            worksheet.write(row,col,0)
        col = col+1
    
    return row+1

# used for reindexing qubits
def swap(perm, a, b):
    temp = perm[a]
    perm[a] = perm[b]
    perm[b] = temp
    
def prepCircuitStrings(length, reps):
    circuits = []
    for i in range(reps):
        circuit = ""
        mat = r2group[""]
        for j in range(length-1):
            genString = random.choice(list(r2group.keys()))
            circuit += genString
            circuit += "8"
            mat = np.matmul(mat,r2group[genString])
        #Find String
        totalString = findGenString(mat)
        
        circuit += totalString[::-1]
        circuit += "8"
        
        circuits.append(circuit)
        print(circuit)
    f = open(str(length)+"-"+str(reps)+"-circuits.pkl", "wb")
    pickle.dump(circuits,f)
    f.close()
    
def loadAllCircuits(length,reps):
    circPickle = open(str(length)+"-"+str(9)+"-circuits.pkl", "rb")
    circuitStrings = pickle.load(circPickle)
    return circuitStrings

# all the important settings are here    
lengths = [6]
reps = [8,9,9,9]
initialStates = [0,1,2,3]
shots = 1024
phased = True
shouldWrite = True


pickle_in = open("r2group.pkl", "rb")
r2group = pickle.load(pickle_in)
pickle_in2 = open("r2group.pickle", "rb")
signedGroup = pickle.load(pickle_in2)

if shouldWrite:
    
    workbook = xlsxwriter.Workbook("uncoded_("+
                                   ",".join(map(str,lengths))+
                                   ")_("+
                                   ",".join(map(str,reps))+
                                   ")_"+
                                   str(int(phased))+
                                   "_"+
                                   str(datetime.datetime.now().strftime('%Y%m%d_%H%M%S'))+
                                   ".xlsx")
    worksheet = workbook.add_worksheet()
    
    states = ["Key","00","01","10","11"]
    for index in range(len(states)):
        worksheet.write(0,index+1,states[index])
    row = 1
    col = 1
  
# Reset this whenever you feel like it
# prepCircuitStrings(15,9)

startTime = time.time()

for length in lengths:
    
    circuits = loadAllCircuits(length,reps[0])
    print(circuits)

    for compiler in initialStates:
        
        print(str(length)+" "+str(compiler)+"\n")
        
        if shouldWrite:
            worksheet.write(row,0, "Length: "+str(length))
            row = row+1
        
        # run our trials
        for i in range(reps[compiler]):

            # run one trial of given length 
            mat = r2group[""]
            n = 2
            qr = QuantumRegister(n)
            cr = ClassicalRegister(n)
            qc = QuantumCircuit(qr, cr)

            perm = {0: 0, 1: 1}
            
            # optional: add phase
            if phased:
                addPhase(qc)
            
            # Deprecated
                '''
            # add the first m-1 clifford gates
            for j in range(length-1):
                mat = addRandCliff(qc,mat,perm)
            
            #Find String
            genString = findGenString(mat)

            # invert everything
            invertCliffGens(qc,genString,perm)'''
            
            circuit = circuits[i]
            addCliffGens(qc,circuit,perm)
            
            # optional: remove phase
            if phased:
                removePhase(qc)

            # get the qc compiled into one of the 4 different states
            compilation(qc,compiler,perm)
            
            # measure
            for i in range(n):
                qc.measure(qr[perm[i]], cr[i])
            
            #initial_layout = { ('q', 0): ('q', 12), ('q', 1): ('q', 5)}
            print(perm)
            print("got")
            job = execute(qc, backend, shots = shots)
            
            #Print Job Status 
            lapse = 0
            interval = 120
            while not job.done:
                print('Status @ {} seconds'.format(interval * lapse))
                print(job.status)
                time.sleep(interval)
                lapse += 1
            print(job.status)
            print("here")
            result = job.result()
            print("nice")
            data = result.get_counts(qc)
            
            # outdated
            print(data)

            # plot_histogram(data)
            
            # set shouldWrite to false if running on simulator or don't actually care
            if shouldWrite:
                row = writeToExcel(data,compiler,row,col)
            
            # optional: get success rate
            desired = toBinString(compiler)
            print(data[desired]/1024)
            
endTime = time.time()
print("Time elapsed: ", endTime-startTime)


if shouldWrite:
    workbook.close()
# Out:
# Qconfig loaded from /Users/Atsushi/Documents/DOMath/Jupyter/quantum_rb/Qconfig.py.
# ['045716846780451467680547682874158', '47684578367684715680471687050648', '134815067684546080824686736458', '0546376815067680246780268134546876158', '24567825480258045148024547683158', '6376851467807680684567862708', '0571685047835468063768135487508', '2456845802454676834518456387545318', '57680456080572684514684676867618']
# 6 0
#
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 120 seconds
# {'job_id': '5b46994a431af20038a1efe8', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 30}
# Status @ 240 seconds
# {'job_id': '5b46994a431af20038a1efe8', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 30}
# Status @ 360 seconds
# {'job_id': '5b46994a431af20038a1efe8', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 480 seconds
# {'job_id': '5b46994a431af20038a1efe8', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 600 seconds
# {'job_id': '5b46994a431af20038a1efe8', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# {'job_id': '5b46994a431af20038a1efe8', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 688, '01': 128, '10': 135, '11': 73}
# 0.671875
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 120 seconds
# {'job_id': '5b469d896f65ec0041463a37', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# {'job_id': '5b469d896f65ec0041463a37', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 688, '10': 141, '01': 123, '11': 72}
# 0.671875
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 120 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 51}
# Status @ 240 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 51}
# Status @ 360 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 51}
# Status @ 480 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 51}
# Status @ 600 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 51}
# Status @ 720 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 48}
# Status @ 840 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 45}
# Status @ 960 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 45}
# Status @ 1080 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 36}
# Status @ 1200 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 36}
# Status @ 1320 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 36}
# Status @ 1440 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 36}
# Status @ 1560 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 36}
# Status @ 1680 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 1800 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 1920 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 2040 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 2160 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 2280 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 2400 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 2520 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 18}
# Status @ 2640 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 18}
# Status @ 2760 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 18}
# Status @ 2880 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 18}
# Status @ 3000 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 15}
# Status @ 3120 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 15}
# Status @ 3240 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 15}
# Status @ 3360 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 12}
# Status @ 3480 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 12}
# Status @ 3600 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 12}
# Status @ 3720 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 9}
# Status @ 3840 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 9}
# Status @ 3960 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 9}
# Status @ 4080 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 9}
# Status @ 4200 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 4320 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 4440 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 4560 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 4680 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 4800 seconds
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# {'job_id': '5b469e7c5ecd23003738c6d6', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 794, '10': 84, '01': 89, '11': 57}
# 0.775390625
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 120 seconds
# {'job_id': '5b46ccda445d95003a9693e2', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 240 seconds
# {'job_id': '5b46ccda445d95003a9693e2', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 360 seconds
# {'job_id': '5b46ccda445d95003a9693e2', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# {'job_id': '5b46ccda445d95003a9693e2', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 677, '01': 103, '10': 125, '11': 119}
# 0.6611328125
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 120 seconds
# {'job_id': '5b46cf045e0e98003a89cc33', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# {'job_id': '5b46cf045e0e98003a89cc33', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 822, '01': 66, '10': 79, '11': 57}
# 0.802734375
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46cff691502f0039a7032a', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 750, '01': 86, '10': 92, '11': 96}
# 0.732421875
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d07091502f0039a70341', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 731, '10': 82, '01': 120, '11': 91}
# 0.7138671875
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d0e95ecd23003738c748', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 702, '10': 123, '01': 111, '11': 88}
# 0.685546875
# 6 1
#
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d162445d95003a9693f1', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 182, '01': 657, '10': 81, '11': 104}
# 0.6416015625
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d1dc431af20038a1f0d9', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 186, '10': 113, '01': 630, '11': 95}
# 0.615234375
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d255188e52003cea6778', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 159, '10': 65, '01': 729, '11': 71}
# 0.7119140625
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d2cf5ecd23003738c74c', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 182, '01': 583, '10': 139, '11': 120}
# 0.5693359375
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d348188e52003cea677e', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 141, '01': 727, '10': 86, '11': 70}
# 0.7099609375
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d3c2445d95003a9693f6', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 163, '01': 642, '10': 119, '11': 100}
# 0.626953125
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d43b431af20038a1f0e1', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 197, '10': 85, '01': 657, '11': 85}
# 0.6416015625
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d4b5431af20038a1f0e8', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 163, '10': 100, '01': 651, '11': 110}
# 0.6357421875
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d52e6bb5720049822f9b', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 156, '01': 669, '10': 109, '11': 90}
# 0.6533203125
# 6 2
#
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d5a7431af20038a1f0ee', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 178, '01': 132, '10': 573, '11': 141}
# 0.5595703125
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d6205ecd23003738c75b', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 191, '10': 607, '01': 96, '11': 130}
# 0.5927734375
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d69a396c1c00393ca7ba', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 131, '10': 756, '01': 63, '11': 74}
# 0.73828125
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 120 seconds
# {'job_id': '5b46d7145ecd23003738c760', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# {'job_id': '5b46d7145ecd23003738c760', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 173, '01': 140, '10': 610, '11': 101}
# 0.595703125
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d8066f65ec0041463abe', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 135, '01': 79, '10': 745, '11': 65}
# 0.7275390625
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d8805375050042187b8c', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 157, '01': 101, '10': 688, '11': 78}
# 0.671875
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d8f9445d95003a969409', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 149, '10': 647, '01': 102, '11': 126}
# 0.6318359375
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d9735e0e98003a89cc51', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 176, '10': 647, '01': 120, '11': 81}
# 0.6318359375
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46d9ec431af20038a1f11b', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 170, '01': 101, '10': 670, '11': 83}
# 0.654296875
# 6 3
#
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 120 seconds
# {'job_id': '5b46da685375050042187b96', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# {'job_id': '5b46da685375050042187b96', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 141, '01': 166, '10': 178, '11': 539}
# 0.5263671875
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46db5b445d95003a96941c', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 101, '10': 210, '01': 170, '11': 543}
# 0.5302734375
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46dbd491502f0039a7039d', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 76, '10': 122, '01': 116, '11': 710}
# 0.693359375
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46dc4d5375050042187b9b', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 114, '01': 195, '10': 133, '11': 582}
# 0.568359375
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46dcc6396c1c00393ca7f3', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 89, '01': 127, '10': 95, '11': 713}
# 0.6962890625
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46dd3f396c1c00393ca7f5', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 115, '01': 133, '10': 139, '11': 637}
# 0.6220703125
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46ddb9431af20038a1f130', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 105, '10': 142, '01': 119, '11': 658}
# 0.642578125
# {0: 1, 1: 0}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# {'job_id': '5b46e04b6bb5720049822fc9', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 119, '10': 166, '01': 164, '11': 575}
# 0.5615234375
# {0: 0, 1: 1}
# got
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 120 seconds
# {'job_id': '5b46e0c5396c1c00393ca801', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# {'job_id': '5b46e0c5396c1c00393ca801', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# here
# nice
# {'00': 133, '01': 168, '10': 129, '11': 594}
# 0.580078125
# Time elapsed:  18539.797820091248
